# %%
from sklearn.datasets import make_blobs

# %%
from sklearn.cluster import KMeans

# %%
X,y = make_blobs(random_state=0, n_samples=1000)

# %%
X
# Out:
# array([[-0.80723584,  2.66946295],
#        [ 1.9263585 ,  4.15243012],
#        [-1.50016563,  3.10133251],
#        ...,
#        [ 0.41230223,  0.49159186],
#        [-2.53294087,  2.09633244],
#        [ 1.10777893,  1.14210712]])

# %%
import matplotlib.pyplot as gambar

# %%
gambar.show()

# %%
plt.plot(X[:,0],X[:,1],'ro')

# %% [markdown]
# plt.show()

# %%
clustering = AgglomerativeClustering(n_clusters=3,linkage="average", affinity='manhattan')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-8b957ca8e025> in <module>()
# ----> 1 clustering = AgglomerativeClustering(n_clusters=3,linkage="average", affinity='manhattan')
#
# NameError: name 'AgglomerativeClustering' is not defined

# %%
clustering.fit(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f2bcf1bc7188> in <module>()
# ----> 1 clustering.fit(x)
#
# NameError: name 'clustering' is not defined

# %%
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(X[:,0],X[:,1],c=kmeans.labels_, marker='o')
plt.show()
